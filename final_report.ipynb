# %%
# %matplotlib inline

# %%
from visualize import Plot
p = Plot();
# Out:
# Makes WORD_COUNT column
# Makes CHAR_COUNT column
# Makes AVG_WORD_LEN column
# Makes NUM_STOPWORDS column
# Makes HAS_LINK column
# Lowercase All CONTENT
# Removing Punctuation
# Removing Stopwords
# Lemmatizing
# Creating TOKENS Column
# Making HAS_CHANNEL column
# Making HAS_SUBSCRIBE column
# Making POLARITY and SUBJECTIVITY COLUMNS

# %%
p.most_common_words_all()

# %%
p.most_common_words_class()

# %%
p.most_common_words_artists()
